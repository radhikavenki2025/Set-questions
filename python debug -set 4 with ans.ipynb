# %%
#1.Identify and fix the syntax error in the following code:


age = 18
if (age >= 18):
    print("You are eligible to vote")

###Ans:syntax error - parenthesis and colon was missing
# Out:
# You are eligible to vote

# %%
#2.Question:
##What error will occur in the following code?


def greet():
    print("Hello, World!")

greet()

#### Ans: greet_user() is not defined
# Out:
# Hello, World!

# %%
#3.Identify the error in this code:

name = "Alice"
age = "25"
print("My name is " + name + " and I am " + age + " years old.")

### we cannot concatenate string and numbers in print statement.,so define age as string
# Out:
# My name is Alice and I am 25 years old.

# %%
#4.Question: What will happen when you run this code?

a = 10
b = 0
result = a / b 
print(result)


##Zero division error
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 5
#       3 a = 10
#       4 b = 0
# ----> 5 result = a / b
#       6 print(result)
#       9 ##Zero division error
#
# ZeroDivisionError: division by zero

# %%
#5.What error will occur in the following code?

num = str("xyz")
print(num)

### xyz is not an integer
# Out:
# xyz

# %%
#6.Identify the issue in this code:

data = {"name": "John", "age": 30}
print(data["city"])


##Ans : No index by the name city is listed

# %%
#7.What will happen when you run this code?
num = 1
while num < 5:
    print(num)

### loop condition is always true, keeps printing 1

# %%
#8.What is wrong with this code?

fruits = ("apple", "banana", "cherry")
print(fruits[3])

### Ans : Index out of range

# %%
#9.What will happen when you run this code?

text = "hello world"
text.append("!")

### Ans: "hello world!" , adds an exclamation mark to the end of the string

# %%
#10.What is wrong with the following code?

import randoms
print(randoms.randint(1, 10))

### random is the name of the library

Ans:
import random
print(random.randint(1,10))
